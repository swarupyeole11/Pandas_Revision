# %% [markdown]
# <a href="https://colab.research.google.com/github/swarupyeole11/Pandas_Revision/blob/main/Implementing_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#defining sigmoid function and visulizing just for fun
x = np.linspace(-10,10,100)

def sigmoid(x):
   return 1/(1+np.exp(-x))

z = sigmoid(x)

plt.plot(x,z)
plt.show()

# %%
class Neural_Network(object):
  def __init__(self):
    #parameters
    self.inputLayerSize = 2
    self.hiddenLayerSize = 3
    self.outputLayerSize = 1

    #defining the weights for the matrix f
    self.Weight_Matrix_layer12 = np.random.randn(self.inputLayerSize,self.hiddenLayerSize)
    self.Weight_Martix_layer23 = np.random.randn(self.hiddenLayerSize,self.outputLayerSize)

  def forward(self,X):
   #propogate through network
   # take dotproduct of x and synapses wright between L1 and l2
   z2 = np.dot(X,self.Weight_Matrix_layer12)
   #apply activation function
   a2 = self.sigmoid(z2)
   #multiplying the a2 o.e o/p of hidden layer with weights of layers 23
   z3 = np.dot(a2,self.Weight_Martix_layer23)
   #applying activation function
   yHat = self.sigmoid(z3)
   return yHat

  def sigmoid(self,z):
    return 1/(1+np.exp(-z))

# %%
nn = Neural_Network()
X = [[3,5],[5,1],[10,2]]
yHat = nn.forward(X)
## printing the predicted value with forward pass
yHat
# Out:
# array([[0.11458209],
#        [0.20538785],
#        [0.15795209]])

# %%
y = [75,82,93]
scaled_y = [0.75,0.82,0.93]
flattened_yHat = np.array(yHat).flatten()
print(flattened_yHat)

x = np.arange(len(y))
plt.bar(x,scaled_y)
plt.bar(x,flattened_yHat)
plt.legend(['Actual','Predicted'])
plt.show()
# Out:
# [0.78532958 0.77722799 0.78666469]
